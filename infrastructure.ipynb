# %% [markdown]
# ## Installs

# %%
dependencies = ['notebook',
     'langchain',
     'langchain[openai]',
     'langchain[prompts]',
     'langchain_core',
     'langchain_classic',
     'langchain_mcp_adapters',
     'langchain-text-splitters',
     'pytest',
     'asyncio',
     'pytest-asyncio',
     'npx',
     'langchain-community',
     'langchain_tavily',
     'langgraph',
     'langchain-pinecone',
     'ipywidgets',
     'setuptools',
     'wheel',
     'dotenv',
     'pydantic',
     'psycopg[binary]',
     'fastmcp',
     'mcp',
     'uvicorn']
with open('requirements.txt', 'w') as f:
     for dep in dependencies:
          f.write(f"{dep}\n")

# %%
! pip install -r requirements.txt
! poetry lock
! poetry install
# Out:
# ...
# WARNING: langchain 1.2.16 does not provide the extra 'prompts'
# ...
# Updating dependencies
# Resolving dependencies... (0.1s)
# Installing dependencies from lock file
#
# Installing the current project: chatbot-a2a (0.1.0)Installing the current project: chatbot-a2a (0.1.0)

# %% [markdown]
# ## Create Folders

# %%
# !mkdir  agent_cards src src/agents src/common src/mcp
# Out:
# mkdir: cannot create directory ‘agent_cards’: File exists
# mkdir: cannot create directory ‘src’: File exists
# mkdir: cannot create directory ‘src/agents’: File exists
# mkdir: cannot create directory ‘src/common’: File exists

# %% [markdown]
# ## Create Files

# %%
# !touch src/common/agent_executor.py src/common/agent_runner.py src/common/base_agent.py src/common/prompts.py src/common/types.py src/common/utils.py src/common/workflow.py

# %%
# !touch src/mcp/client.py src/mcp/server.py

# %%
# !touch src/agents/langgraph_planner.py src/agents/orchestrator.py src/agents/__main__.py

# %%
# !touch  agent_cards/langgraph_planner_agent.json agent_cards/orchestrator_agent.json
